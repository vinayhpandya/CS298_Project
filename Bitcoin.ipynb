# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayhpandya/CS298_Project/blob/main/Bitcoin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -c "import torch; print(torch.version.cuda)"
# Out:
# 11.8

# %%
# !python -c "import torch; print(torch.__version__)"
# Out:
# 2.1.0+cu118

# %%
# !pip install -q torch-cluster -f https://data.pyg.org/whl/torch-1.10.0+cu113.html

# %%
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.11.0+cu113.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-1.11.0+cu113.html
# !pip install torch-geometric

# %%
from torch_geometric.datasets import EllipticBitcoinDataset

# %%
from torch_geometric.transforms import NormalizeFeatures

# %%
from torch_geometric.nn import Node2Vec

# %%
raw_data = EllipticBitcoinDataset(root="/")

# %%
dataset=EllipticBitcoinDataset(root="/",transform=NormalizeFeatures())

# %%
print("Number of Features: " + str(dataset.num_features))
data = dataset[0]
# Out:
# Number of Features: 165

# %%
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-1.11.0+${CUDA}.html

# %%
import torch_cluster

# %%
import torch

# %%
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# %%
import torch_geometric

# %%
# !pip install torch-cluster
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.9/dist-packages (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from torch-cluster) (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.9/dist-packages (from scipy->torch-cluster) (1.22.4)

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# !pip install torch-geometric

# %%
import torch; print(torch.__version__)
# Out:
# 2.0.0+cu118

# %%
model = Node2Vec(data.edge_index, embedding_dim=165, walk_length=20,
             context_size=10, walks_per_node=10,num_negative_samples=1, p=1, q=1, sparse=True).to(device)

loader = model.loader(batch_size=128, shuffle=True, num_workers=4)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-f4fda76a99e2> in <cell line: 1>()
# ----> 1 model = Node2Vec(data.edge_index, embedding_dim=165, walk_length=20,
#       2              context_size=10, walks_per_node=10,num_negative_samples=1, p=1, q=1, sparse=True).to(device)
#       3
#       4 loader = model.loader(batch_size=128, shuffle=True, num_workers=4)
#
# /usr/local/lib/python3.9/dist-packages/torch_geometric/nn/models/node2vec.py in __init__(self, edge_index, embedding_dim, walk_length, context_size, walks_per_node, p, q, num_negative_samples, num_nodes, sparse)
#      64         super().__init__()
#      65
# ---> 66         if random_walk is None:
#      67             raise ImportError('`Node2Vec` requires `torch-cluster`.')
#      68
#
# ImportError: `Node2Vec` requires `torch-cluster`.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
optimizer = torch.optim.SparseAdam(list(model.parameters()), lr=0.01)
def train():
    model.train()
    total_loss = 0
    for pos_rw, neg_rw in loader:
        optimizer.zero_grad()
        loss = model.loss(pos_rw.to(device), neg_rw.to(device))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)


@torch.no_grad()
def test():
    model.eval()
    z = model()
    acc = model.test(z[data.train_mask], data.y[data.train_mask],
                     z[data.test_mask], data.y[data.test_mask],
                     max_iter=10)
    return acc


for epoch in range(1, 100):
    loss = train()
    #acc = test()
    print(f'Epoch: {epoch:02d}, Loss: {loss:.4f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-c9108ead8106> in <cell line: 1>()
# ----> 1 optimizer = torch.optim.SparseAdam(list(model.parameters()), lr=0.01)
#       2 def train():
#       3     model.train()
#       4     total_loss = 0
#       5     for pos_rw, neg_rw in loader:
#
# NameError: name 'model' is not defined

# %%
# !python --version
# Out:
# Python 3.9.16
